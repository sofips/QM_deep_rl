# %%
from environment import *
import numpy as np
import os

# %%
os.system('python3 config_experiment.py config.ini' )
# Out:
# 0

# %%
env = MyEnv('config.ini')

for i in range(70):
    print(env.step(i%16))
# Out:
# Spectral Decomposition: checked
# State Propagation: checked
# (array([ 9.88792108e-01,  0.00000000e+00,  0.00000000e+00, -1.48878159e-01,
#        -1.11868610e-02,  0.00000000e+00,  0.00000000e+00,  5.59973491e-04,
#         2.10147754e-05,  0.00000000e+00,  0.00000000e+00, -6.30781318e-07,
#        -1.57758734e-08,  0.00000000e+00,  0.00000000e+00,  3.38160132e-10,
#         6.34208806e-12,  0.00000000e+00,  0.00000000e+00, -1.05744733e-13]), array([ 9.88792108e-01+0.00000000e+00j,  0.00000000e+00-1.48878159e-01j,
#        -1.11868610e-02+0.00000000e+00j,  0.00000000e+00+5.59973491e-04j,
#         2.10147754e-05+0.00000000e+00j,  0.00000000e+00-6.30781318e-07j,
#        -1.57758734e-08+0.00000000e+00j,  0.00000000e+00+3.38160132e-10j,
#         6.34208806e-12+0.00000000e+00j,  0.00000000e+00-1.05744733e-13j]), 1, 1.1181948564447831e-26, 1.062285113622544e-25, False)
# (array([-7.52928476e-01, -6.39219533e-01, -1.70859844e-02, -1.51942518e-01,
# ...
